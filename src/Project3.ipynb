# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
import requests
import time
import datetime as dt
import pymongo
import ast
from config import USER, PASSWORD, CLIENT_ID, CLIENT_SECRET
# Import API key
#from api_keys import CLIENT_ID, CLIENT_SECRET

# CLIENT_ID = "lxOoFeO416HkSlXFiuVTU"
# CLIENT_SECRET = "PWsQxpgJ7G1tgN1wlO0122bPEbOwZiU1g7SCwUBe"

# %%
# boundaries
bottom = 25
top = 49
left = -126
right = -66
add_prcp = "&filter=prcp"
add_snow= "&filter=snow"

# %%
df_maxtemp = pd.DataFrame([], columns = {'Date','Date(ISO)', 'Lat', 'Long', 'Temp(F)'})
df_mintemp = pd.DataFrame([], columns = {'Date','Date(ISO)', 'Lat', 'Long', 'Temp(F)'})
df_prcp = pd.DataFrame([], columns = {'Date','Date(ISO)', 'Lat', 'Long', 'Prcp(in)'})
df_snow = pd.DataFrame([], columns = {'Date','Date(ISO)', 'Lat', 'Long', 'Snow(in)'})

df_snow = df_snow[['Date','Date(ISO)',  'Lat', 'Long', 'Snow(in)']]
df_prcp = df_prcp[['Date','Date(ISO)',  'Lat', 'Long', 'Prcp(in)']]
df_maxtemp = df_maxtemp[['Date', 'Date(ISO)', 'Lat', 'Long', 'Temp(F)']]
df_mintemp = df_mintemp[['Date', 'Date(ISO)', 'Lat', 'Long', 'Temp(F)']]

height = (top-bottom)/15
width = (right-left)/40

# %%
##MAXTEMP
#for i in range(15):
for i in range(15):
    box_top = round(top - i*height,4)
    box_bottom = round(box_top - height,4)
    #for j in range(40):
    for j in range(40):
        box_left = round(left + j*height,4)
        box_right = round(box_left + width,4)
        
        query_url = f"https://api.aerisapi.com/records/within?format=geojson&p={box_bottom},{box_left},{box_top},{box_right}&limit=2000&from=01/01/1950&to=now&client_id={CLIENT_ID}&client_secret={CLIENT_SECRET}&filter=maxt"
        weather_response = requests.get(query_url)
        weather_json = weather_response.json()
        print(i*40+j, len(weather_json['features']), box_bottom, box_left, box_top, box_right)
        for k in range(len(weather_json['features'])):
            response = weather_json['features'][k]

            fahr_temp = response['properties']['report']['details']['tempF']
            lat = response['geometry']['coordinates'][1]
            lon = response['geometry']['coordinates'][0]
            date = response['properties']['report']['timestamp']
            dateiso = response['properties']['report']['dateTimeISO']
            
            df_maxtemp = df_maxtemp.append(pd.Series([date, dateiso, lat, lon, fahr_temp], index=df_maxtemp.columns ), ignore_index=True)
# Out:
# 0 239 47.4 -126.0 49.0 -124.5
# 1 1000 47.4 -124.4 49.0 -122.9
# 2 1000 47.4 -122.8 49.0 -121.3
# 3 1000 47.4 -121.2 49.0 -119.7
# 4 1000 47.4 -119.6 49.0 -118.1
# 5 1000 47.4 -118.0 49.0 -116.5
# 6 1000 47.4 -116.4 49.0 -114.9
# 7 1000 47.4 -114.8 49.0 -113.3
# 8 1000 47.4 -113.2 49.0 -111.7
# 9 1000 47.4 -111.6 49.0 -110.1
# 10 1000 47.4 -110.0 49.0 -108.5

# %%
##MINTEMP
#for i in range(15):
for i in range(15):
    box_top = round(top - i*height,4)
    box_bottom = round(box_top - height,4)
    #for j in range(40):
    for j in range(40):
        box_left = round(left + j*height,4)
        box_right = round(box_left + width,4)
        
        query_url = f"https://api.aerisapi.com/records/within?format=geojson&p={box_bottom},{box_left},{box_top},{box_right}&limit=2000&from=01/01/1950&to=now&client_id={CLIENT_ID}&client_secret={CLIENT_SECRET}&filter=mint"
        weather_response = requests.get(query_url)
        weather_json = weather_response.json()
        print(i*40+j, len(weather_json['features']), box_bottom, box_left, box_top, box_right)
        for k in range(len(weather_json['features'])):
            response = weather_json['features'][k]

            fahr_temp = response['properties']['report']['details']['tempF']
            lat = response['geometry']['coordinates'][1]
            lon = response['geometry']['coordinates'][0]
            date = response['properties']['report']['timestamp']
            dateiso = response['properties']['report']['dateTimeISO']
            
            df_mintemp = df_mintemp.append(pd.Series([date, dateiso, lat, lon, fahr_temp], index=df_mintemp.columns ), ignore_index=True)
# Out:
# 0 157 47.4 -126.0 49.0 -124.5
# 1 1000 47.4 -124.4 49.0 -122.9
# 2 1000 47.4 -122.8 49.0 -121.3
# 3 1000 47.4 -121.2 49.0 -119.7
# 4 1000 47.4 -119.6 49.0 -118.1
# 5 1000 47.4 -118.0 49.0 -116.5
# 6 1000 47.4 -116.4 49.0 -114.9
# 7 1000 47.4 -114.8 49.0 -113.3
# 8 1000 47.4 -113.2 49.0 -111.7
# 9 1000 47.4 -111.6 49.0 -110.1
# 10 1000 47.4 -110.0 49.0 -108.5
# 11 1000 47.4 -108.4 49.0 -106.9
# 12 1000 47.4 -106.8 49.0 -105.3
# 13 1000 47.4 -105.2 49.0 -103.7
# 14 1000 47.4 -103.6 49.0 -102.1
# 15 1000 47.4 -102.0 49.0 -100.5
# 16 1000 47.4 -100.4 49.0 -98.9
# 17 1000 47.4 -98.8 49.0 -97.3
# 18 1000 47.4 -97.2 49.0 -95.7
# 19 1000 47.4 -95.6 49.0 -94.1
# 20 1000 47.4 -94.0 49.0 -92.5
# 21 1000 47.4 -92.4 49.0 -90.9
# 22 1000 47.4 -90.8 49.0 -89.3
# 23 316 47.4 -89.2 49.0 -87.7
# 24 0 47.4 -87.6 49.0 -86.1
# 25 0 47.4 -86.0 49.0 -84.5
# 26 0 47.4 -84.4 49.0 -82.9
# 27 0 47.4 -82.8 49.0 -81.3
# 28 0 47.4 -81.2 49.0 -79.7
# 29 0 47.4 -79.6 49.0 -78.1
# 30 0 47.4 -78.0 49.0 -76.5
# ...

# %%
##PRCP
#for i in range(15):
for i in range(3):
    box_top = round(top - i*height,4)
    box_bottom = round(box_top - height,4)
    #for j in range(40):
    for j in range(3):
        box_left = round(left + j*height,4)
        box_right = round(box_left + width,4)
        
        query_url = f"https://api.aerisapi.com/records/within?format=geojson&p={box_bottom},{box_left},{box_top},{box_right}&limit=2000&from=01/01/2000&to=now&client_id={CLIENT_ID}&client_secret={CLIENT_SECRET}&filter=prcp"
        weather_response = requests.get(query_url)
        weather_json = weather_response.json()
        print(i*40+j, len(weather_json['features']), box_bottom, box_left, box_top, box_right)
        for k in range(len(weather_json['features'])):
            
            response = weather_json['features'][k]

            prcp = response['properties']['report']['details']['prcpIN']
            lat = response['geometry']['coordinates'][1]
            lon = response['geometry']['coordinates'][0]
            date = response['properties']['report']['timestamp']
            dateiso = response['properties']['report']['dateTimeISO']
            
            df_prcp = df_prcp.append(pd.Series([date, dateiso, lat, lon, prcp], index=df_prcp.columns ), ignore_index=True)
# Out:
# 0 158 47.4 -126.0 49.0 -124.5
# 1 358 47.4 -124.4 49.0 -122.9
# 2 1000 47.4 -122.8 49.0 -121.3
# 40 0 45.8 -126.0 47.4 -124.5
# 41 1000 45.8 -124.4 47.4 -122.9
# 42 1000 45.8 -122.8 47.4 -121.3
# 80 0 44.2 -126.0 45.8 -124.5
# 81 1000 44.2 -124.4 45.8 -122.9
# 82 1000 44.2 -122.8 45.8 -121.3

# %%
##SNOW
#for i in range(15):
for i in range(3):
    box_top = round(top - i*height,4)
    box_bottom = round(box_top - height,4)
    #for j in range(40):
    for j in range(3):
        box_left = round(left + j*height,4)
        box_right = round(box_left + width,4)
        
        query_url = f"https://api.aerisapi.com/records/within?format=geojson&p={box_bottom},{box_left},{box_top},{box_right}&limit=2000&from=01/01/2000&to=now&client_id={CLIENT_ID}&client_secret={CLIENT_SECRET}&filter=snow"
        weather_response = requests.get(query_url)
        weather_json = weather_response.json()
        print(i*40+j, len(weather_json['features']), box_bottom, box_left, box_top, box_right)
        for k in range(len(weather_json['features'])):
            response = weather_json['features'][k]

            snow = response['properties']['report']['details']['snowIN']
            lat = response['geometry']['coordinates'][1]
            lon = response['geometry']['coordinates'][0]
            date = response['properties']['report']['timestamp']
            dateiso = response['properties']['report']['dateTimeISO']
            
            df_snow = df_snow.append(pd.Series([date, dateiso lat, lon, snow], index=df_snow.columns ), ignore_index=True)
# Out:
# 0 1 47.4 -126.0 49.0 -124.5
# 1 60 47.4 -124.4 49.0 -122.9
# 2 499 47.4 -122.8 49.0 -121.3
# 40 0 45.8 -126.0 47.4 -124.5
# 41 128 45.8 -124.4 47.4 -122.9
# 42 515 45.8 -122.8 47.4 -121.3
# 80 0 44.2 -126.0 45.8 -124.5
# 81 222 44.2 -124.4 45.8 -122.9
# 82 582 44.2 -122.8 45.8 -121.3

# %%
query_url = f"https://api.aerisapi.com/records/within?p={box_bottom},{box_left},{box_top},{box_right}&limit=2000&from=01/01/2000&to=now&client_id={CLIENT_ID}&client_secret={CLIENT_SECRET}&filter=maxt"
weather_response = requests.get(query_url)
weather_json = weather_response.json()

# %%
conn = f'mongodb+srv://admin:password2@weatherviz-andy-5dubo.mongodb.net/weatherviz?retryWrites=true'
client = pymongo.MongoClient(conn)
db = client.weatherviz
mint_json = df_mintemp.to_json()
db.min_temp.insert_one(ast.literal_eval(mint_json))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-55f146298a9a> in <module>()
#       5
#       6
# ----> 7 db.min_temp.insert_one(ast.literal_eval(mint_json))
#
# ~\Anaconda3\lib\ast.py in literal_eval(node_or_string)
#      83                     return left - right
#      84         raise ValueError('malformed node or string: ' + repr(node))
# ---> 85     return _convert(node_or_string)
#      86
#      87
#
# ~\Anaconda3\lib\ast.py in _convert(node)
#      64         elif isinstance(node, Dict):
#      65             return dict((_convert(k), _convert(v)) for k, v
# ---> 66                         in zip(node.keys, node.values))
#      67         elif isinstance(node, NameConstant):
#      68             return node.value
#
# ~\Anaconda3\lib\ast.py in <genexpr>(.0)
#      63             return set(map(_convert, node.elts))
# ...

# %%
# Out:
# Empty DataFrame
# Columns: [Date, Date(ISO), Lat, Long, Temp(F)]
# Index: []

# %%
df_mintemp.to_csv('mintemp.csv')

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-e56e4a6d51b9> in <module>()
# ----> 1 dt.datetime.strptime(date)
#
# TypeError: strptime() takes exactly 2 arguments (1 given)

# %%
response
# Out:
# {'type': 'Feature',
#  'id': '5c1bf4c66bcc5a20c9ce69e0',
#  'geometry': {'type': 'Point', 'coordinates': [-124.555, 47.9375]},
#  'properties': {'id': '5c1bf4c66bcc5a20c9ce69e0',
#   'loc': {'long': -124.555, 'lat': 47.9375},
#   'report': {'timestamp': 1544774400,
#    'dateTimeISO': '2018-12-14T00:00:00-08:00',
#    'code': 3,
#    'type': 'maxt',
#    'station': {'id': 'USW00094240',
#     'type': None,
#     'name': 'quillayute state airport'},
#    'location': 'quillayute state airport',
#    'details': {'text': '13.3', 'tempC': 13.3, 'tempF': 55.9},
#    'tied': False,
#    'prev': {'timestamp': 1039852800,
#     'dateTimeISO': '2002-12-14T00:00:00-08:00',
#     'details': {'text': '12.8', 'tempC': 12.8, 'tempF': 55}}},
#   'place': {'name': 'quillayute state ap', 'state': 'wa', 'country': 'us'},
#   'profile': {'tz': 'America/Los_Angeles'}}}

# %%
fahr_temp = response['properties']['report']['details']['tempF']
lat = response['geometry']['coordinates'][1]
lon = response['geometry']['coordinates'][0]
date = response['properties']['report']['timestamp']
dateiso = response['properties']['report']['dateTimeISO']

fahr_temp, lat, lon, date, dateiso
# Out:
# (55.9, 47.9375, -124.555, 1544774400, '2018-12-14T00:00:00-08:00')

# %%
df_maxtemp
# Out:
#              Date                  Date(ISO)      Lat      Long  Temp(F)
# 0      1544774400  2018-12-14T00:00:00-08:00  47.9375 -124.5550     55.9
# 1      1539763200  2018-10-17T01:00:00-07:00  47.9375 -124.5550     73.9
# 2      1539676800  2018-10-16T01:00:00-07:00  47.9375 -124.5550     80.1
# 3      1539590400  2018-10-15T01:00:00-07:00  47.9375 -124.5550     73.9
# 4      1524556800  2018-04-24T01:00:00-07:00  47.9375 -124.5550     75.9
# 5      1516003200  2018-01-15T00:00:00-08:00  47.9375 -124.5550     63.0
# 6      1515916800  2018-01-14T00:00:00-08:00  47.9375 -124.5550     57.9
# 7      1512892800  2017-12-10T00:00:00-08:00  47.9375 -124.5550     59.0
# 8      1511337600  2017-11-22T00:00:00-08:00  47.9375 -124.5550     57.9
# 9      1504425600  2017-09-03T01:00:00-07:00  47.9375 -124.5550     88.0
# 10     1503907200  2017-08-28T01:00:00-07:00  47.9375 -124.5550     91.9
# 11     1503820800  2017-08-27T01:00:00-07:00  47.9375 -124.5550     91.0
# ...
